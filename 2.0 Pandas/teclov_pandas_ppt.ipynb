# %% [markdown]
# # create Pandas Series

# %%
import pandas as pd

# %%
a = pd.Series([1,2,3,4,5])

# %%
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a[2]
# Out:
# 3

# %%
a = pd.Series(['a','b','c'])

# %%
a
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
a = pd.date_range(start = '01-01-2018', end = '23-5-2018')

# %%
a
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08',
#                '2018-01-09', '2018-01-10',
#                ...
#                '2018-05-14', '2018-05-15', '2018-05-16', '2018-05-17',
#                '2018-05-18', '2018-05-19', '2018-05-20', '2018-05-21',
#                '2018-05-22', '2018-05-23'],
#               dtype='datetime64[ns]', length=143, freq='D')

# %%
type(a)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# # Pandas dataframe

# %%
import numpy as np

# %%
temp = np.random.randint(low = 20, high =100, size = [20,])
name = np.random.choice(['Abhay','Teclov','Geekshub','Ankit'],20)
random = np.random.choice([10,11,13,12,14],20)

# %%
a = list(zip(temp, name, random))

# %%
df = pd.DataFrame(data = a, columns=['temp','name','random'])

# %%
df
# Out:
#     temp      name  random
# 0     62     Ankit      12
# 1     32  Geekshub      14
# 2     59     Abhay      14
# 3     83    Teclov      10
# 4     50    Teclov      14
# 5     66     Ankit      13
# 6     89     Abhay      11
# 7     92     Abhay      10
# 8     54     Abhay      11
# 9     56     Abhay      13
# 10    39  Geekshub      12
# 11    78  Geekshub      10
# 12    67  Geekshub      12
# 13    28     Abhay      10
# 14    38  Geekshub      12
# 15    23    Teclov      14
# 16    50    Teclov      14
# 17    46  Geekshub      10
# 18    88    Teclov      13
# 19    66    Teclov      12

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
temp = np.random.randint(low = 20, high =100, size = [20,])
name = np.random.choice(['Abhay','Teclov','Geekshub','Ankit'],20)
random = np.random.choice([10,11,13,12,14],20)

# %%
df = pd.DataFrame({'temp':temp, 'name':name, 'random':random})

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    temp      name  random
# 0    26    Teclov      10
# 1    36  Geekshub      13
# 2    70     Ankit      12
# 3    27  Geekshub      13
# 4    43  Geekshub      11

# %%
df.tail()
# Out:
#     temp      name  random
# 15    34     Ankit      13
# 16    42    Teclov      12
# 17    22    Teclov      10
# 18    83  Geekshub      11
# 19    80     Abhay      13

# %%
df.shape
# Out:
# (20, 3)

# %%
df.columns
# Out:
# Index(['temp', 'name', 'random'], dtype='object')

# %%
df.name
# Out:
# 0       Teclov
# 1     Geekshub
# 2        Ankit
# 3     Geekshub
# 4     Geekshub
# 5        Abhay
# 6        Ankit
# 7        Abhay
# 8     Geekshub
# 9     Geekshub
# 10      Teclov
# 11      Teclov
# 12    Geekshub
# 13      Teclov
# 14       Abhay
# 15       Ankit
# 16      Teclov
# 17      Teclov
# 18    Geekshub
# 19       Abhay
# Name: name, dtype: object

# %%
df['name']
# Out:
# 0       Teclov
# 1     Geekshub
# 2        Ankit
# 3     Geekshub
# 4     Geekshub
# 5        Abhay
# 6        Ankit
# 7        Abhay
# 8     Geekshub
# 9     Geekshub
# 10      Teclov
# 11      Teclov
# 12    Geekshub
# 13      Teclov
# 14       Abhay
# 15       Ankit
# 16      Teclov
# 17      Teclov
# 18    Geekshub
# 19       Abhay
# Name: name, dtype: object

# %%
df['temp'].describe()
# Out:
# count    20.00000
# mean     55.10000
# std      22.97344
# min      22.00000
# 25%      35.50000
# 50%      56.00000
# 75%      76.00000
# max      94.00000
# Name: temp, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   temp    20 non-null     int32
#  1   name    20 non-null     object
#  2   random  20 non-null     int32
# dtypes: int32(2), object(1)
# memory usage: 448.0+ bytes

# %%
df.values
# Out:
# array([[26, 'Teclov', 10],
#        [36, 'Geekshub', 13],
#        [70, 'Ankit', 12],
#        [27, 'Geekshub', 13],
#        [43, 'Geekshub', 11],
#        [28, 'Abhay', 10],
#        [94, 'Ankit', 14],
#        [38, 'Abhay', 10],
#        [63, 'Geekshub', 10],
#        [76, 'Geekshub', 10],
#        [49, 'Teclov', 14],
#        [83, 'Teclov', 12],
#        [63, 'Geekshub', 13],
#        [76, 'Teclov', 10],
#        [69, 'Abhay', 10],
#        [34, 'Ankit', 13],
#        [42, 'Teclov', 12],
#        [22, 'Teclov', 10],
#        [83, 'Geekshub', 11],
#        [80, 'Abhay', 13]], dtype=object)

# %%
df
# Out:
#     temp      name  random
# 0     26    Teclov      10
# 1     36  Geekshub      13
# 2     70     Ankit      12
# 3     27  Geekshub      13
# 4     43  Geekshub      11
# 5     28     Abhay      10
# 6     94     Ankit      14
# 7     38     Abhay      10
# 8     63  Geekshub      10
# 9     76  Geekshub      10
# 10    49    Teclov      14
# 11    83    Teclov      12
# 12    63  Geekshub      13
# 13    76    Teclov      10
# 14    69     Abhay      10
# 15    34     Ankit      13
# 16    42    Teclov      12
# 17    22    Teclov      10
# 18    83  Geekshub      11
# 19    80     Abhay      13

# %%
df.set_index('temp', inplace = True)

# %%
df
# Out:
#           name  random
# temp
# 39      Teclov      13
# 84       Ankit      10
# 71      Teclov      12
# 53      Teclov      11
# 34    Geekshub      12
# 78    Geekshub      11
# 43       Abhay      10
# 87    Geekshub      12
# 34    Geekshub      12
# 71    Geekshub      13
# 54       Ankit      12
# 83       Abhay      12
# 23      Teclov      12
# 82       Ankit      13
# 44      Teclov      10
# 44       Ankit      13
# 98       Abhay      11
# 92       Ankit      14
# 82      Teclov      10
# 70    Geekshub      10

# %%
df.sort_index(axis =0, ascending=False)
# Out:
#           name  random
# temp
# 94       Ankit      14
# 83      Teclov      12
# 83    Geekshub      11
# 80       Abhay      13
# 76      Teclov      10
# 76    Geekshub      10
# 70       Ankit      12
# 69       Abhay      10
# 63    Geekshub      13
# 63    Geekshub      10
# 49      Teclov      14
# 43    Geekshub      11
# 42      Teclov      12
# 38       Abhay      10
# 36    Geekshub      13
# 34       Ankit      13
# 28       Abhay      10
# 27    Geekshub      13
# 26      Teclov      10
# 22      Teclov      10

# %%
df.sort_values(by ='random', ascending = False)
# Out:
#           name  random
# temp
# 49      Teclov      14
# 94       Ankit      14
# 34       Ankit      13
# 63    Geekshub      13
# 36    Geekshub      13
# 80       Abhay      13
# 27    Geekshub      13
# 83      Teclov      12
# 70       Ankit      12
# 42      Teclov      12
# 43    Geekshub      11
# 83    Geekshub      11
# 28       Abhay      10
# 38       Abhay      10
# 63    Geekshub      10
# 76    Geekshub      10
# 76      Teclov      10
# 69       Abhay      10
# 22      Teclov      10
# 26      Teclov      10

# %%
df.drop(['random'], axis =1)
# Out:
#           name
# temp
# 26      Teclov
# 36    Geekshub
# 70       Ankit
# 27    Geekshub
# 43    Geekshub
# 28       Abhay
# 94       Ankit
# 38       Abhay
# 63    Geekshub
# 76    Geekshub
# 49      Teclov
# 83      Teclov
# 63    Geekshub
# 76      Teclov
# 69       Abhay
# 34       Ankit
# 42      Teclov
# 22      Teclov
# 83    Geekshub
# 80       Abhay

# %%
df.head()
# Out:
#           name  random
# temp
# 26      Teclov      10
# 36    Geekshub      13
# 70       Ankit      12
# 27    Geekshub      13
# 43    Geekshub      11

# %%
df.iloc[[0,1]]
# Out:
#           name  random
# temp
# 26      Teclov      10
# 36    Geekshub      13

# %%
df.iloc[1:3,1]
# Out:
# temp
# 36    13
# 70    12
# Name: random, dtype: int32

# %%
df.iloc[[True,True,False,True]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df.iloc[[True,True,False,True]]
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\indexing.py:1701, in _iLocIndexer._getitem_axis(self, key, axis)
#    1699 if com.is_bool_indexer(key):
#    1700     self._validate_key(key, axis)
# -> 1701     return self._getbool_axis(key, axis=axis)
#    1703 # a list of integers
#    1704 elif is_list_like_indexer(key):
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\indexing.py:1171, in _LocationIndexer._getbool_axis(self, key, axis)
#    1167 @final
#    1168 def _getbool_axis(self, key, axis: AxisInt):
#    1169     # caller is responsible for ensuring non-None axis
#    1170     labels = self.obj._get_axis(axis)
# -> 1171     key = check_bool_indexer(labels, key)
#    1172     inds = key.nonzero()[0]
#    1173     return self.obj._take_with_is_copy(inds, axis=axis)
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\indexing.py:2594, in check_bool_indexer(index, key)
#    2590 elif not is_array_like(result):
#    2591     # GH 33924
#    2592     # key may contain nan elements, check_array_indexer needs bool array
#    2593     result = pd_array(result, dtype=bool)
# -> 2594 return check_array_indexer(index, result)
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\indexers\utils.py:539, in check_array_indexer(array, indexer)
#     537     # GH26658
#     538     if len(indexer) != len(array):
# --> 539         raise IndexError(
#     540             f"Boolean index has wrong length: "
#     541             f"{len(indexer)} instead of {len(array)}"
#     542         )
#     543 elif is_integer_dtype(dtype):
#     544     try:
#
# IndexError: Boolean index has wrong length: 4 instead of 20

# %%
df.head()
# Out:
#           name  random
# temp
# 26      Teclov      10
# 36    Geekshub      13
# 70       Ankit      12
# 27    Geekshub      13
# 43    Geekshub      11

# %%
df.loc[26,:]
# Out:
# name      Teclov
# random        10
# Name: 26, dtype: object

# %%
df.loc[[36,70,27]]
# Out:
#           name  random
# temp
# 36    Geekshub      13
# 70       Ankit      12
# 27    Geekshub      13

# %%
df.loc[[36, 70],'name':'random']
# Out:
#           name  random
# temp
# 36    Geekshub      13
# 70       Ankit      12

# %%
df.loc[[True, True, False, True]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df.loc[[True, True, False, True]]
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\indexing.py:1375, in _LocIndexer._getitem_axis(self, key, axis)
#    1373     return self._get_slice_axis(key, axis=axis)
#    1374 elif com.is_bool_indexer(key):
# -> 1375     return self._getbool_axis(key, axis=axis)
#    1376 elif is_list_like_indexer(key):
#    1377     # an iterable multi-selection
#    1378     if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\indexing.py:1171, in _LocationIndexer._getbool_axis(self, key, axis)
#    1167 @final
#    1168 def _getbool_axis(self, key, axis: AxisInt):
#    1169     # caller is responsible for ensuring non-None axis
#    1170     labels = self.obj._get_axis(axis)
# -> 1171     key = check_bool_indexer(labels, key)
#    1172     inds = key.nonzero()[0]
#    1173     return self.obj._take_with_is_copy(inds, axis=axis)
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\indexing.py:2594, in check_bool_indexer(index, key)
#    2590 elif not is_array_like(result):
#    2591     # GH 33924
#    2592     # key may contain nan elements, check_array_indexer needs bool array
#    2593     result = pd_array(result, dtype=bool)
# -> 2594 return check_array_indexer(index, result)
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\indexers\utils.py:539, in check_array_indexer(array, indexer)
#     537     # GH26658
#     538     if len(indexer) != len(array):
# --> 539         raise IndexError(
#     540             f"Boolean index has wrong length: "
#     541             f"{len(indexer)} instead of {len(array)}"
#     542         )
#     543 elif is_integer_dtype(dtype):
#     544     try:
#
# IndexError: Boolean index has wrong length: 4 instead of 20

# %%
df.loc[df.random > 13]
# Out:
#         name  random
# temp
# 94     Ankit      14
# 49    Teclov      14

# %%
df.loc[(df.random > 13) | (df.random == 10),:]
# Out:
#           name  random
# temp
# 26      Teclov      10
# 28       Abhay      10
# 94       Ankit      14
# 38       Abhay      10
# 63    Geekshub      10
# 76    Geekshub      10
# 49      Teclov      14
# 76      Teclov      10
# 69       Abhay      10
# 22      Teclov      10

# %%
# Merging & concat
d1 = pd.DataFrame([['a', 1], ['b', 2]],columns=['col1', 'number'])
d2 = pd.DataFrame([['c', 3, 'lion'], ['d', 4, 'tiger']],columns=['letter', 'number', 'animal'])

# %%
d1
# Out:
#   col1  number
# 0    a       1
# 1    b       2

# %%
d2
# Out:
#   letter  number animal
# 0      c       3   lion
# 1      d       4  tiger

# %%
pd.concat([d1,d2],axis =0)
# Out:
#   col1  number letter animal
# 0    a       1    NaN    NaN
# 1    b       2    NaN    NaN
# 0  NaN       3      c   lion
# 1  NaN       4      d  tiger

# %%
pd.concat([d1,d2], axis =0, ignore_index=True)
# Out:
#   col1  number letter animal
# 0    a       1    NaN    NaN
# 1    b       2    NaN    NaN
# 2  NaN       3      c   lion
# 3  NaN       4      d  tiger

# %%
pd.concat([d1,d2], axis = 1)
# Out:
#   col1  number letter  number animal
# 0    a       1      c       3   lion
# 1    b       2      d       4  tiger

# %%
d1 = pd.DataFrame({
    "city" : ["lucknow","kanpur","agra","delhi"],
    "temperature" : [32,45,30,40]
})

# %%
d1
# Out:
#       city  temperature
# 0  lucknow           32
# 1   kanpur           45
# 2     agra           30
# 3    delhi           40

# %%
d2 = pd.DataFrame({
    "city" : ["delhi","lucknow","kanpur"],
    "humidity" : [68,65,75]
})

# %%
d2
# Out:
#       city  humidity
# 0    delhi        68
# 1  lucknow        65
# 2   kanpur        75

# %%
df = pd.merge(d1,d2, on='city')

# %%
df
# Out:
#       city  temperature  humidity
# 0  lucknow           32        65
# 1   kanpur           45        75
# 2    delhi           40        68

# %%
pd.merge(d1,d2, on=['city'], how ='outer')
# Out:
#       city  temperature  humidity
# 0  lucknow           32      65.0
# 1   kanpur           45      75.0
# 2     agra           30       NaN
# 3    delhi           40      68.0

# %%
pd.merge(d1, d2, on =['city'], how='left')
# Out:
#       city  temperature  humidity
# 0  lucknow           32      65.0
# 1   kanpur           45      75.0
# 2     agra           30       NaN
# 3    delhi           40      68.0

# %%
# dataset from https://github.com/codebasics/py/blob/master/pandas/6_handling_missing_data_replace/weather_data.csv

# %%
df1 = pd.read_csv("weather_data.csv")

# %%
df1
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
# pip3 install openpyxl
df1.to_excel('df_xl.xlsx', sheet_name = 'weather_data', index=False)

# %%
# pip3 install xlrd
df2 = pd.read_excel('df_xl.xlsx')

# %%
df2
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df2.to_csv('file.csv')

# %%
df2.to_csv('file_noindex.csv', index = False)

# %%
df_group = df2.groupby("event")

# %%
df_group

# %%
for temperature in df_group:
    print(temperature)
# Out:
# ('Rain',         day  temperature  windspeed event
# 0  1/1/2017           32          6  Rain
# 4  1/5/2017           32          4  Rain)
# ('Snow',         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow)
# ('Sunny',         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 5  1/6/2017           31          2  Sunny)

# %%
df_group.get_group('Rain')
# Out:
#         day  temperature  windspeed event
# 0  1/1/2017           32          6  Rain
# 4  1/5/2017           32          4  Rain

# %%
df_group.describe()
# Out:
#       temperature                                               windspeed  \
#             count  mean       std   min   25%   50%   75%   max     count
# event
# Rain          2.0  32.0  0.000000  32.0  32.0  32.0  32.0  32.0       2.0
# Snow          2.0  26.0  2.828427  24.0  25.0  26.0  27.0  28.0       2.0
# Sunny         2.0  33.0  2.828427  31.0  32.0  33.0  34.0  35.0       2.0
#
#
#       mean       std  min   25%  50%   75%  max
# event
# Rain   5.0  1.414214  4.0  4.50  5.0  5.50  6.0
# Snow   4.5  3.535534  2.0  3.25  4.5  5.75  7.0
# Sunny  4.5  3.535534  2.0  3.25  4.5  5.75  7.0

# %%
def hot_temp(x):
    return x > 30

# %%
df2['hot_temp'] = df2['temperature'].apply(hot_temp)

# %%
df2
# Out:
#         day  temperature  windspeed  event  hot_temp
# 0  1/1/2017           32          6   Rain      True
# 1  1/2/2017           35          7  Sunny      True
# 2  1/3/2017           28          2   Snow     False
# 3  1/4/2017           24          7   Snow     False
# 4  1/5/2017           32          4   Rain      True
# 5  1/6/2017           31          2  Sunny      True

# %%
df2['hot_temp'] = df2['temperature'].apply(lambda x: x > 30)

# %%
df2
# Out:
#         day  temperature  windspeed  event  hot_temp
# 0  1/1/2017           32          6   Rain      True
# 1  1/2/2017           35          7  Sunny      True
# 2  1/3/2017           28          2   Snow     False
# 3  1/4/2017           24          7   Snow     False
# 4  1/5/2017           32          4   Rain      True
# 5  1/6/2017           31          2  Sunny      True

# %%
#pivot table

# %%
df2.pivot_table(values = 'temperature', index = 'event', aggfunc = 'mean')
# Out:
#        temperature
# event
# Rain          32.0
# Snow          26.0
# Sunny         33.0

# %%
df2
# Out:
#         day  temperature  windspeed  event  hot_temp
# 0  1/1/2017           32          6   Rain      True
# 1  1/2/2017           35          7  Sunny      True
# 2  1/3/2017           28          2   Snow     False
# 3  1/4/2017           24          7   Snow     False
# 4  1/5/2017           32          4   Rain      True
# 5  1/6/2017           31          2  Sunny      True

# %%
df2.pivot_table(columns = 'temperature')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\groupby\ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\groupby\ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
#     878     res = extract_result(res)
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\groupby\groupby.py:2380, in GroupBy.mean.<locals>.<lambda>(x)
#    2377 else:
#    2378     result = self._cython_agg_general(
#    2379         "mean",
# -> 2380         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2381         numeric_only=numeric_only,
#    2382     )
#    2383     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\series.py:6225, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6217 @doc(make_doc("mean", ndim=1))
#    6218 def mean(
#    6219     self,
#    (...)
#    6223     **kwargs,
#    6224 ):
# -> 6225     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\generic.py:11992, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11985 def mean(
#   11986     self,
#   11987     axis: Axis | None = 0,
#    (...)
#   11990     **kwargs,
#   11991 ) -> Series | float:
# > 11992     return self._stat_function(
#   11993         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11994     )
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\generic.py:11949, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11947 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11949 return self._reduce(
#   11950     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11951 )
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\series.py:6133, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6129     raise TypeError(
#    6130         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6131         "with non-numeric dtypes."
#    6132     )
# -> 6133 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\nanops.py:1693, in _ensure_numeric(x)
#    1691 if isinstance(x, str):
#    1692     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1693     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1694 try:
#
# TypeError: Could not convert string '1/4/2017' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 df2.pivot_table(columns = 'temperature')
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\frame.py:9190, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9173 @Substitution("")
#    9174 @Appender(_shared_docs["pivot_table"])
#    9175 def pivot_table(
#    (...)
#    9186     sort: bool = True,
#    9187 ) -> DataFrame:
#    9188     from pandas.core.reshape.pivot import pivot_table
# -> 9190     return pivot_table(
#    9191         self,
#    9192         values=values,
#    9193         index=index,
#    9194         columns=columns,
#    9195         aggfunc=aggfunc,
#    9196         fill_value=fill_value,
#    9197         margins=margins,
#    9198         dropna=dropna,
#    9199         margins_name=margins_name,
#    9200         observed=observed,
#    9201         sort=sort,
#    9202     )
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\reshape\pivot.py:99, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      96     table = concat(pieces, keys=keys, axis=1)
#      97     return table.__finalize__(data, method="pivot_table")
# ---> 99 table = __internal_pivot_table(
#     100     data,
#     101     values,
#     102     index,
#     103     columns,
#     104     aggfunc,
#     105     fill_value,
#     106     margins,
#     107     dropna,
#     108     margins_name,
#     109     observed,
#     110     sort,
#     111 )
#     112 return table.__finalize__(data, method="pivot_table")
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\reshape\pivot.py:169, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     166     values = list(values)
#     168 grouped = data.groupby(keys, observed=observed, sort=sort, dropna=dropna)
# --> 169 agged = grouped.agg(aggfunc)
#     171 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     172     agged = agged.dropna(how="all")
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\groupby\generic.py:1445, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1442     kwargs["engine_kwargs"] = engine_kwargs
#    1444 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1445 result = op.agg()
#    1446 if not is_dict_like(func) and result is not None:
#    1447     # GH #52849
#    1448     if not self.as_index and is_list_like(func):
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\apply.py:172, in Apply.agg(self)
#     169 kwargs = self.kwargs
#     171 if isinstance(func, str):
# --> 172     return self.apply_str()
#     174 if is_dict_like(func):
#     175     return self.agg_dict_like()
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\apply.py:586, in Apply.apply_str(self)
#     584         else:
#     585             self.kwargs["axis"] = self.axis
# --> 586 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\apply.py:669, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     667 f = getattr(obj, func)
#     668 if callable(f):
# --> 669     return f(*args, **kwargs)
#     671 # people may aggregate on a non-callable attribute
#     672 # but don't let them think they can pass args to it
#     673 assert len(args) == 0
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\groupby\groupby.py:2378, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2371     return self._numba_agg_general(
#    2372         grouped_mean,
#    2373         executor.float_dtype_mapping,
#    2374         engine_kwargs,
#    2375         min_periods=0,
#    2376     )
#    2377 else:
# -> 2378     result = self._cython_agg_general(
#    2379         "mean",
#    2380         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2381         numeric_only=numeric_only,
#    2382     )
#    2383     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\groupby\groupby.py:1929, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1926     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1927     return result
# -> 1929 new_mgr = data.grouped_reduce(array_func)
#    1930 res = self._wrap_agged_manager(new_mgr)
#    1931 out = self._wrap_aggregated_output(res)
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\internals\managers.py:1428, in BlockManager.grouped_reduce(self, func)
#    1424 if blk.is_object:
#    1425     # split on object-dtype blocks bc some columns may raise
#    1426     #  while others do not.
#    1427     for sb in blk._split():
# -> 1428         applied = sb.apply(func)
#    1429         result_blocks = extend_blocks(applied, result_blocks)
#    1430 else:
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\internals\blocks.py:366, in Block.apply(self, func, **kwargs)
#     360 @final
#     361 def apply(self, func, **kwargs) -> list[Block]:
#     362     """
#     363     apply the function to my values; return a block if we are not
#     364     one
#     365     """
# --> 366     result = func(self.values, **kwargs)
#     368     result = maybe_coerce_values(result)
#     369     return self._split_op_result(result)
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\groupby\groupby.py:1926, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1923 else:
#    1924     return result
# -> 1926 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1927 return result
#
# File c:\Users\aiman\anaconda3\envs\CareerUpSkill\lib\site-packages\pandas\core\groupby\groupby.py:1878, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1876     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1877     # preserve the kind of exception that raised
# -> 1878     raise type(err)(msg) from err
#    1880 if ser.dtype == object:
#    1881     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
help(pd.DataFrame.pivot_table)
# Out:
# Help on function pivot_table in module pandas.core.frame:
#
# pivot_table(self, values=None, index=None, columns=None, aggfunc: 'AggFuncType' = 'mean', fill_value=None, margins: 'bool' = False, dropna: 'bool' = True, margins_name: 'Level' = 'All', observed: 'bool' = False, sort: 'bool' = True) -> 'DataFrame'
#     Create a spreadsheet-style pivot table as a DataFrame.
#
#     The levels in the pivot table will be stored in MultiIndex objects
#     (hierarchical indexes) on the index and columns of the result DataFrame.
#
#     Parameters
#     ----------
#     values : list-like or scalar, optional
#         Column or columns to aggregate.
#     index : column, Grouper, array, or list of the previous
#         Keys to group by on the pivot table index. If a list is passed,
#         it can contain any of the other types (except list). If an array is
#         passed, it must be the same length as the data and will be used in
#         the same manner as column values.
#     columns : column, Grouper, array, or list of the previous
#         Keys to group by on the pivot table column. If a list is passed,
#         it can contain any of the other types (except list). If an array is
#         passed, it must be the same length as the data and will be used in
#         the same manner as column values.
#     aggfunc : function, list of functions, dict, default "mean"
#         If a list of functions is passed, the resulting pivot table will have
#         hierarchical columns whose top level are the function names
#         (inferred from the function objects themselves).
#         If a dict is passed, the key is column to aggregate and the value is
#         function or list of functions. If ``margin=True``, aggfunc will be
#         used to calculate the partial aggregates.
#     fill_value : scalar, default None
#         Value to replace missing values with (in the resulting pivot table,
#         after aggregation).
#     margins : bool, default False
#         If ``margins=True``, special ``All`` columns and rows
#         will be added with partial group aggregates across the categories
#         on the rows and columns.
#     dropna : bool, default True
#         Do not include columns whose entries are all NaN. If True,
#         rows with a NaN value in any column will be omitted before
#         computing margins.
#     margins_name : str, default 'All'
#         Name of the row / column that will contain the totals
#         when margins is True.
#     observed : bool, default False
#         This only applies if any of the groupers are Categoricals.
#         If True: only show observed values for categorical groupers.
#         If False: show all values for categorical groupers.
#
#     sort : bool, default True
#         Specifies if the result should be sorted.
#
#         .. versionadded:: 1.3.0
#
#     Returns
#     -------
#     DataFrame
#         An Excel style pivot table.
#
#     See Also
#     --------
#     DataFrame.pivot : Pivot without aggregation that can handle
#         non-numeric data.
#     DataFrame.melt: Unpivot a DataFrame from wide to long format,
#         optionally leaving identifiers set.
#     wide_to_long : Wide panel to long format. Less flexible but more
#         user-friendly than melt.
#
#     Notes
#     -----
#     Reference :ref:`the user guide <reshaping.pivot>` for more examples.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({"A": ["foo", "foo", "foo", "foo", "foo",
#     ...                          "bar", "bar", "bar", "bar"],
#     ...                    "B": ["one", "one", "one", "two", "two",
#     ...                          "one", "one", "two", "two"],
#     ...                    "C": ["small", "large", "large", "small",
#     ...                          "small", "large", "small", "small",
#     ...                          "large"],
#     ...                    "D": [1, 2, 2, 3, 3, 4, 5, 6, 7],
#     ...                    "E": [2, 4, 5, 5, 6, 6, 8, 9, 9]})
#     >>> df
#          A    B      C  D  E
#     0  foo  one  small  1  2
#     1  foo  one  large  2  4
#     2  foo  one  large  2  5
#     3  foo  two  small  3  5
#     4  foo  two  small  3  6
#     5  bar  one  large  4  6
#     6  bar  one  small  5  8
#     7  bar  two  small  6  9
#     8  bar  two  large  7  9
#
#     This first example aggregates values by taking the sum.
#
#     >>> table = pd.pivot_table(df, values='D', index=['A', 'B'],
#     ...                        columns=['C'], aggfunc="sum")
#     >>> table
#     C        large  small
#     A   B
#     bar one    4.0    5.0
#         two    7.0    6.0
#     foo one    4.0    1.0
#         two    NaN    6.0
#
#     We can also fill missing values using the `fill_value` parameter.
#
#     >>> table = pd.pivot_table(df, values='D', index=['A', 'B'],
#     ...                        columns=['C'], aggfunc="sum", fill_value=0)
#     >>> table
#     C        large  small
#     A   B
#     bar one      4      5
#         two      7      6
#     foo one      4      1
#         two      0      6
#
#     The next example aggregates by taking the mean across multiple columns.
#
#     >>> table = pd.pivot_table(df, values=['D', 'E'], index=['A', 'C'],
#     ...                        aggfunc={'D': "mean", 'E': "mean"})
#     >>> table
#                     D         E
#     A   C
#     bar large  5.500000  7.500000
#         small  5.500000  8.500000
#     foo large  2.000000  4.500000
#         small  2.333333  4.333333
#
#     We can also calculate multiple types of aggregations for any given
#     value column.
#
#     >>> table = pd.pivot_table(df, values=['D', 'E'], index=['A', 'C'],
#     ...                        aggfunc={'D': "mean",
#     ...                                 'E': ["min", "max", "mean"]})
#     >>> table
#                       D   E
#                    mean max      mean  min
#     A   C
#     bar large  5.500000   9  7.500000    6
#         small  5.500000   9  8.500000    8
#     foo large  2.000000   5  4.500000    4
#         small  2.333333   6  4.333333    2
